# %%
# boilerplate to resolve directories...
import sys
from pathlib import Path
sys.path.append(str(Path(".").resolve().parent))

# %%
from scripts.sch import *

# %%
city_map, initial_incomes, incomes, swap_history = run_simulation()
# Out:
# Generating Map...
# Initializing Agents...
# Starting Simulation (500 steps)...
# Step 0: Swaps performed = 1832
# Step 10: Swaps performed = 184
# Step 20: Swaps performed = 81
# Step 30: Swaps performed = 51
# Step 40: Swaps performed = 32
# Step 50: Swaps performed = 30
# Step 60: Swaps performed = 19
# Step 70: Swaps performed = 21
# Step 80: Swaps performed = 18
# Step 90: Swaps performed = 21
# Step 100: Swaps performed = 18
# Step 110: Swaps performed = 17
# Step 120: Swaps performed = 30
# Step 130: Swaps performed = 21
# Step 140: Swaps performed = 21
# Step 150: Swaps performed = 23
# Step 160: Swaps performed = 21
# Step 170: Swaps performed = 25
# Step 180: Swaps performed = 18
# Step 190: Swaps performed = 22
# Step 200: Swaps performed = 17
# Step 210: Swaps performed = 17
# Step 220: Swaps performed = 17
# Step 230: Swaps performed = 11
# Step 240: Swaps performed = 12
# Step 250: Swaps performed = 13
# Step 260: Swaps performed = 11
# Step 270: Swaps performed = 11
# ...

# %%
plot_results(city_map=city_map, init_inc=initial_incomes,
             final_inc=incomes, swap_history=swap_history)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 plot_results(city_map=city_map, init_inc=initial_incomes,
#       2              final_inc=incomes)
#
# TypeError: plot_results() missing 1 required positional argument: 'swap_history'
