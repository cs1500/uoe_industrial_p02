# %%
# boilerplate to resolve directories...
import sys
from pathlib import Path
sys.path.append(str(Path(".").resolve().parent))

# %%
from scripts.sch import *

# %%
city_map, initial_incomes, incomes = run_simulation()
# Out:
# Generating Map...
# Initializing Agents...
# Starting Simulation (50 steps)...
# Step 0: Swaps performed = 1859
# Step 10: Swaps performed = 198
# Step 20: Swaps performed = 74
# Step 30: Swaps performed = 57
# Step 40: Swaps performed = 44

# %%
plot_results(city_map=city_map, init_inc=initial_incomes,
             final_inc=incomes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 plot_results(city_map=city_map, init_inc=init_inc, final_inc=final_inc)
#
# NameError: name 'init_inc' is not defined
