# %%
# boilerplate to resolve directories...
import sys
from pathlib import Path
sys.path.append(str(Path(".").resolve().parent))

# %%
from scripts.sch import *

# %%
city, start_inc, end_inc, swaps, seg = run_simulation()
# Out:
# Generating Map...
# Initializing Agents...
# Starting Simulation (800 steps)...
# Step 0: Swaps = 1832, Segregation = 0.210
# Step 10: Swaps = 184, Segregation = 0.302
# Step 20: Swaps = 81, Segregation = 0.317
# Step 30: Swaps = 51, Segregation = 0.323
# Step 40: Swaps = 32, Segregation = 0.328
# Step 50: Swaps = 30, Segregation = 0.333
# Step 60: Swaps = 19, Segregation = 0.340
# Step 70: Swaps = 21, Segregation = 0.344
# Step 80: Swaps = 18, Segregation = 0.347
# Step 90: Swaps = 21, Segregation = 0.351
# Step 100: Swaps = 18, Segregation = 0.355
# Step 110: Swaps = 17, Segregation = 0.358
# Step 120: Swaps = 30, Segregation = 0.359
# Step 130: Swaps = 21, Segregation = 0.361
# Step 140: Swaps = 21, Segregation = 0.366
# Step 150: Swaps = 23, Segregation = 0.368
# Step 160: Swaps = 21, Segregation = 0.369
# Step 170: Swaps = 25, Segregation = 0.370
# Step 180: Swaps = 18, Segregation = 0.373
# Step 190: Swaps = 22, Segregation = 0.375
# Step 200: Swaps = 17, Segregation = 0.377
# ...

# %%
plot_results(city, start_inc, end_inc, swaps, seg)
